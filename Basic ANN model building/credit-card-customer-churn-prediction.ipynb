# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/credit-card-customer-churn-prediction/Churn_Modelling.csv

# %%
df = pd.read_csv('/kaggle/input/credit-card-customer-churn-prediction/Churn_Modelling.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.drop(columns = ['RowNumber','CustomerId','Surname'],inplace=True)

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df['Geography'].value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Male      5457
# Female    4543
# Name: Gender, dtype: int64

# %%
df = pd.get_dummies(df,columns=['Geography','Gender'],drop_first=True)

# %%
df.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0               1        101348.88       1                  0
# 1               1        112542.58       0                  0
# 2               0        113931.57       1                  0
# 3               0         93826.63       0                  0
# 4               1         79084.10       0                  0
#
#    Geography_Spain  Gender_Male
# 0                0            0
# 1                1            0
# 2                0            0
# 3                0            0
# 4                1            0

# %%
X = df.drop(columns=['Exited'])
y = df['Exited'].values

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %% [markdown]
# ## scale the train an test

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_train_trf = scaler.fit_transform(X_train)
X_test_trf = scaler.transform(X_test)

# %% [markdown]
# ## import keras

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import Dense

# %% [markdown]
# ## model building (sequential model)

# %%
model = Sequential()
# hidden layer
model.add(Dense(11,activation='sigmoid',input_dim=11))

model.add(Dense(11,activation='sigmoid'))
#output layer
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 11)                132
# _________________________________________________________________
# dense_1 (Dense)              (None, 11)                132
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 12
# =================================================================
# Total params: 276
# Trainable params: 276
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])

# %% [markdown]
# ## train the neural network

# %%
history = model.fit(X_train,y_train,batch_size=50,epochs=100,verbose=1,validation_split=0.2)
# Out:
# Epoch 1/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.6304 - accuracy: 0.6605 - val_loss: 0.5390 - val_accuracy: 0.7975
# Epoch 2/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5194 - accuracy: 0.7972 - val_loss: 0.5104 - val_accuracy: 0.7975
# Epoch 3/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5079 - accuracy: 0.7972 - val_loss: 0.5067 - val_accuracy: 0.7975
# Epoch 4/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5056 - accuracy: 0.7972 - val_loss: 0.5050 - val_accuracy: 0.7975
# Epoch 5/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5042 - accuracy: 0.7972 - val_loss: 0.5033 - val_accuracy: 0.7975
# Epoch 6/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5029 - accuracy: 0.7972 - val_loss: 0.5018 - val_accuracy: 0.7975
# Epoch 7/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5016 - accuracy: 0.7972 - val_loss: 0.5005 - val_accuracy: 0.7975
# Epoch 8/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5007 - accuracy: 0.7972 - val_loss: 0.4995 - val_accuracy: 0.7975
# Epoch 9/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4998 - accuracy: 0.7972 - val_loss: 0.4986 - val_accuracy: 0.7975
# Epoch 10/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4994 - accuracy: 0.7972 - val_loss: 0.4980 - val_accuracy: 0.7975
# Epoch 11/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4988 - accuracy: 0.7972 - val_loss: 0.4975 - val_accuracy: 0.7975
# Epoch 12/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4985 - accuracy: 0.7972 - val_loss: 0.4971 - val_accuracy: 0.7975
# Epoch 13/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4982 - accuracy: 0.7972 - val_loss: 0.4968 - val_accuracy: 0.7975
# Epoch 14/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4979 - accuracy: 0.7972 - val_loss: 0.4966 - val_accuracy: 0.7975
# Epoch 15/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4979 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 16/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4978 - accuracy: 0.7972 - val_loss: 0.4963 - val_accuracy: 0.7975
# Epoch 17/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4979 - accuracy: 0.7972 - val_loss: 0.4961 - val_accuracy: 0.7975
# Epoch 18/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4976 - accuracy: 0.7972 - val_loss: 0.4961 - val_accuracy: 0.7975
# Epoch 19/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4977 - accuracy: 0.7972 - val_loss: 0.4960 - val_accuracy: 0.7975
# Epoch 20/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4977 - accuracy: 0.7972 - val_loss: 0.4960 - val_accuracy: 0.7975
# Epoch 21/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4976 - accuracy: 0.7972 - val_loss: 0.4960 - val_accuracy: 0.7975
# Epoch 22/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4976 - accuracy: 0.7972 - val_loss: 0.4959 - val_accuracy: 0.7975
# Epoch 23/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4976 - accuracy: 0.7972 - val_loss: 0.4959 - val_accuracy: 0.7975
# Epoch 24/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4975 - accuracy: 0.7972 - val_loss: 0.4959 - val_accuracy: 0.7975
# Epoch 25/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4976 - accuracy: 0.7972 - val_loss: 0.4959 - val_accuracy: 0.7975
# Epoch 26/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4974 - accuracy: 0.7972 - val_loss: 0.4959 - val_accuracy: 0.7975
# Epoch 27/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4975 - accuracy: 0.7972 - val_loss: 0.4960 - val_accuracy: 0.7975
# Epoch 28/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4975 - accuracy: 0.7972 - val_loss: 0.4959 - val_accuracy: 0.7975
# Epoch 29/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4975 - accuracy: 0.7972 - val_loss: 0.4959 - val_accuracy: 0.7975
# Epoch 30/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4974 - accuracy: 0.7972 - val_loss: 0.4959 - val_accuracy: 0.7975
# Epoch 31/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4974 - accuracy: 0.7972 - val_loss: 0.4961 - val_accuracy: 0.7975
# Epoch 32/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4974 - accuracy: 0.7972 - val_loss: 0.4962 - val_accuracy: 0.7975
# Epoch 33/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4975 - accuracy: 0.7972 - val_loss: 0.4961 - val_accuracy: 0.7975
# Epoch 34/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4973 - accuracy: 0.7972 - val_loss: 0.4959 - val_accuracy: 0.7975
# Epoch 35/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4974 - accuracy: 0.7972 - val_loss: 0.4960 - val_accuracy: 0.7975
# Epoch 36/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4974 - accuracy: 0.7972 - val_loss: 0.4960 - val_accuracy: 0.7975
# Epoch 37/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4973 - accuracy: 0.7972 - val_loss: 0.4960 - val_accuracy: 0.7975
# Epoch 38/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4974 - accuracy: 0.7972 - val_loss: 0.4960 - val_accuracy: 0.7975
# Epoch 39/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4973 - accuracy: 0.7972 - val_loss: 0.4959 - val_accuracy: 0.7975
# Epoch 40/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4973 - accuracy: 0.7972 - val_loss: 0.4962 - val_accuracy: 0.7975
# Epoch 41/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4975 - accuracy: 0.7972 - val_loss: 0.4960 - val_accuracy: 0.7975
# Epoch 42/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4973 - accuracy: 0.7972 - val_loss: 0.4960 - val_accuracy: 0.7975
# Epoch 43/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4976 - accuracy: 0.7972 - val_loss: 0.4960 - val_accuracy: 0.7975
# Epoch 44/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4973 - accuracy: 0.7972 - val_loss: 0.4960 - val_accuracy: 0.7975
# Epoch 45/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4973 - accuracy: 0.7972 - val_loss: 0.4960 - val_accuracy: 0.7975
# Epoch 46/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4974 - accuracy: 0.7972 - val_loss: 0.4960 - val_accuracy: 0.7975
# Epoch 47/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4972 - accuracy: 0.7972 - val_loss: 0.4961 - val_accuracy: 0.7975
# Epoch 48/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4973 - accuracy: 0.7972 - val_loss: 0.4961 - val_accuracy: 0.7975
# Epoch 49/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4974 - accuracy: 0.7972 - val_loss: 0.4961 - val_accuracy: 0.7975
# Epoch 50/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4972 - accuracy: 0.7972 - val_loss: 0.4961 - val_accuracy: 0.7975
# Epoch 51/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4975 - accuracy: 0.7972 - val_loss: 0.4961 - val_accuracy: 0.7975
# Epoch 52/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4975 - accuracy: 0.7972 - val_loss: 0.4961 - val_accuracy: 0.7975
# Epoch 53/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4973 - accuracy: 0.7972 - val_loss: 0.4961 - val_accuracy: 0.7975
# Epoch 54/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4973 - accuracy: 0.7972 - val_loss: 0.4961 - val_accuracy: 0.7975
# Epoch 55/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4970 - accuracy: 0.7972 - val_loss: 0.4962 - val_accuracy: 0.7975
# Epoch 56/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4973 - accuracy: 0.7972 - val_loss: 0.4961 - val_accuracy: 0.7975
# Epoch 57/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4972 - accuracy: 0.7972 - val_loss: 0.4963 - val_accuracy: 0.7975
# Epoch 58/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4972 - accuracy: 0.7972 - val_loss: 0.4961 - val_accuracy: 0.7975
# Epoch 59/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4972 - accuracy: 0.7972 - val_loss: 0.4963 - val_accuracy: 0.7975
# Epoch 60/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4973 - accuracy: 0.7972 - val_loss: 0.4962 - val_accuracy: 0.7975
# Epoch 61/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4973 - accuracy: 0.7972 - val_loss: 0.4962 - val_accuracy: 0.7975
# Epoch 62/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4972 - accuracy: 0.7972 - val_loss: 0.4962 - val_accuracy: 0.7975
# Epoch 63/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4973 - accuracy: 0.7972 - val_loss: 0.4962 - val_accuracy: 0.7975
# Epoch 64/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4971 - accuracy: 0.7972 - val_loss: 0.4963 - val_accuracy: 0.7975
# Epoch 65/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4971 - accuracy: 0.7972 - val_loss: 0.4962 - val_accuracy: 0.7975
# Epoch 66/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4973 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 67/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4972 - accuracy: 0.7972 - val_loss: 0.4962 - val_accuracy: 0.7975
# Epoch 68/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4971 - accuracy: 0.7972 - val_loss: 0.4962 - val_accuracy: 0.7975
# Epoch 69/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4972 - accuracy: 0.7972 - val_loss: 0.4962 - val_accuracy: 0.7975
# Epoch 70/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4972 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 71/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4971 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 72/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4970 - accuracy: 0.7972 - val_loss: 0.4965 - val_accuracy: 0.7975
# Epoch 73/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4972 - accuracy: 0.7972 - val_loss: 0.4963 - val_accuracy: 0.7975
# Epoch 74/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4972 - accuracy: 0.7972 - val_loss: 0.4962 - val_accuracy: 0.7975
# Epoch 75/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4975 - accuracy: 0.7972 - val_loss: 0.4963 - val_accuracy: 0.7975
# Epoch 76/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4973 - accuracy: 0.7972 - val_loss: 0.4965 - val_accuracy: 0.7975
# Epoch 77/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4972 - accuracy: 0.7972 - val_loss: 0.4963 - val_accuracy: 0.7975
# Epoch 78/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4971 - accuracy: 0.7972 - val_loss: 0.4963 - val_accuracy: 0.7975
# Epoch 79/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4971 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 80/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4973 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 81/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4972 - accuracy: 0.7972 - val_loss: 0.4963 - val_accuracy: 0.7975
# Epoch 82/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4972 - accuracy: 0.7972 - val_loss: 0.4966 - val_accuracy: 0.7975
# Epoch 83/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4970 - accuracy: 0.7972 - val_loss: 0.4965 - val_accuracy: 0.7975
# Epoch 84/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4972 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 85/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4970 - accuracy: 0.7972 - val_loss: 0.4966 - val_accuracy: 0.7975
# Epoch 86/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4971 - accuracy: 0.7972 - val_loss: 0.4965 - val_accuracy: 0.7975
# Epoch 87/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4972 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 88/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4971 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 89/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4971 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 90/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4970 - accuracy: 0.7972 - val_loss: 0.4965 - val_accuracy: 0.7975
# Epoch 91/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4971 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 92/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4969 - accuracy: 0.7972 - val_loss: 0.4965 - val_accuracy: 0.7975
# Epoch 93/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4970 - accuracy: 0.7972 - val_loss: 0.4965 - val_accuracy: 0.7975
# Epoch 94/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4970 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 95/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4970 - accuracy: 0.7972 - val_loss: 0.4966 - val_accuracy: 0.7975
# Epoch 96/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4972 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 97/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4971 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 98/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4970 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 99/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4970 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 100/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4971 - accuracy: 0.7972 - val_loss: 0.4965 - val_accuracy: 0.7975

# %% [markdown]
# # all weights and biases of our model

# %%
model.layers[0].get_weights()
# Out:
# [array([[ 0.2539432 ,  0.30445373, -0.5005434 ,  0.33632106,  0.13622397,
#          -0.23771992,  0.2615255 , -0.01551991,  0.02172154,  0.38875002,
#          -0.12041578],
#         [ 0.28792933,  0.3774443 ,  0.46653277, -0.16102822, -0.41032445,
#           0.5006234 ,  0.15205768, -0.15560824,  0.35005575, -0.37653098,
#          -0.02623713],
#         [ 0.35882768, -0.37246975, -0.34039637,  0.47687522,  0.29387927,
#           0.29491425,  0.41298056, -0.14385419,  0.36993587, -0.5277479 ,
#           0.2745943 ],
#         [-0.12149804,  0.2012431 ,  0.03297335, -0.1459086 ,  0.44457817,
#          -0.32070696, -0.32108885,  0.37552518, -0.16569197,  0.05842563,
#          -0.45317322],
#         [-0.3455489 , -0.16046147, -0.242623  , -0.20030162, -0.4721575 ,
#           0.43498743,  0.26473725, -0.4267795 ,  0.35189563, -0.5086506 ,
#           0.2737412 ],
#         [ 0.22944774,  0.08013929, -0.44686404, -0.28927684,  0.08583063,
#           0.45389527,  0.05081182, -0.5080376 , -0.4613438 , -0.22615162,
#          -0.3478133 ],
#         [-0.18840583,  0.50715506, -0.04311633, -0.21982165,  0.02596295,
#          -0.49753812, -0.4071755 , -0.25833035, -0.0580081 , -0.2519384 ,
#           0.08444107],
#         [ 0.02846636,  0.00542891,  0.14854312, -0.41083917,  0.47576046,
#          -0.20490405, -0.44438264, -0.23960358,  0.06381959, -0.40788132,
#          -0.24081275],
#         [-0.4581678 , -0.2089586 ,  0.19011497, -0.09062973, -0.09958038,
#           0.01075953, -0.4283677 ,  0.38142866, -0.27113268, -0.23264752,
#           0.18077177],
#         [-0.01052543, -0.39747298, -0.01904851,  0.4733899 , -0.46114483,
#           0.47295052,  0.02626848, -0.10771869,  0.47221702, -0.4477567 ,
#          -0.10745203],
#         [-0.02176023, -0.30773047,  0.22985101, -0.16675325, -0.41425124,
#          -0.31437242, -0.07160211,  0.31429088, -0.41817406, -0.17994565,
#          -0.28168628]], dtype=float32),
#  array([ 8.1208639e-02,  8.2428781e-03,  2.2755633e-09, -6.1380770e-02,
#          0.0000000e+00,  0.0000000e+00,  1.7056832e-02,  1.6896760e-02,
#          0.0000000e+00, -2.3476560e-02,  0.0000000e+00], dtype=float32)]

# %% [markdown]
# # make prediction

# %%
y_pred = model.predict(X_test_trf)

# %%
y_pred
# Out:
# array([[0.11247998],
#        [0.1215288 ],
#        [0.1022945 ],
#        ...,
#        [0.10208762],
#        [0.19734749],
#        [0.14134762]], dtype=float32)

# %%
y_pred = y_pred.argmax(axis=-1)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.7925

# %% [markdown]
# ## Graph plotting

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
